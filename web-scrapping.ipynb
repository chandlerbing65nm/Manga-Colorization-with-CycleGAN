# %% [markdown]
# <a href="https://www.kaggle.com/code/chandlertimm/web-scrapping-black-clover-manga-colorization?scriptVersionId=95655542" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import bs4
import requests
import lxml

from pprint import pprint
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# # Parse all websites of the Manga

# %% [markdown]
# ## colored

# %%
html_text = requests.get('https://ww7.readblackclover.com/manga/black-clover-colored/', 'r').text
soup = BeautifulSoup(html_text, 'lxml')

cl_chapters = soup.find_all('div', class_ = 'bg-bg-secondary p-3 rounded mb-3 shadow')
cl_chapter_site = []
for chapter in cl_chapters:
    site = chapter.find('a', class_ = 'uppercase text-xs bg-text-success text-white font-bold py-1 px-2 rounded').attrs['href']
    cl_chapter_site.append(site)

cl_chapter_site.sort()
pprint(len(cl_chapter_site))
# Out:
# 90

# %% [markdown]
# ## black-white

# %%
html_text = requests.get('https://ww7.readblackclover.com/manga/black-clover/', 'r').text
soup = BeautifulSoup(html_text, 'lxml')

bw_chapters = soup.find_all('div', class_ = 'bg-bg-secondary p-3 rounded mb-3 shadow')
bw_chapter_site = []
for chapter in bw_chapters:
    site = chapter.find('a', class_ = 'uppercase text-xs bg-text-success text-white font-bold py-1 px-2 rounded').attrs['href']
    bw_chapter_site.append(site)

bw_chapter_site.sort()
pprint(len(bw_chapter_site))
# Out:
# 332

# %%
cl_chapters = []
bw_chapters = []
for i in tqdm(range(len(cl_chapter_site))):
    for j in range(len(bw_chapter_site)):
        if cl_chapter_site[i][-3:None] == bw_chapter_site[j][-3:None]:
            cl_chapters.append(cl_chapter_site[i])
            bw_chapters.append(bw_chapter_site[j])
        
cl_chapters.sort()
bw_chapters.sort()
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 5470.59it/s]

# %%
pprint(len(cl_chapters))
pprint(len(bw_chapters))

pprint(cl_chapters[-5:None])
pprint(bw_chapters[-5:None])
# Out:
# 90
# 90
# ['https://ww7.readblackclover.com/chapter/black-clover-colored-chapter-308',
#  'https://ww7.readblackclover.com/chapter/black-clover-colored-chapter-309',
#  'https://ww7.readblackclover.com/chapter/black-clover-colored-chapter-310',
#  'https://ww7.readblackclover.com/chapter/black-clover-colored-chapter-319',
#  'https://ww7.readblackclover.com/chapter/black-clover-colored-chapter-320']
# ['https://ww7.readblackclover.com/chapter/black-clover-chapter-308',
#  'https://ww7.readblackclover.com/chapter/black-clover-chapter-309',
#  'https://ww7.readblackclover.com/chapter/black-clover-chapter-310',
#  'https://ww7.readblackclover.com/chapter/black-clover-chapter-319',
#  'https://ww7.readblackclover.com/chapter/black-clover-chapter-320']
